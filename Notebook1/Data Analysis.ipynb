# %% [markdown]
# # Data Analysis of the Indian Pines hyperspectral image dataset
#
# This notebook depicts different visualizations of the indian pines dataset.

# %% [markdown]
# ### 1. Importing modules

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Read the dataset

# %%
df = pd.read_csv('Dataset.csv')

# %% [markdown]
# Showing initial 5 rows of the dataset

# %%
df.describe()
# Out:
#              band-1        band-2        band-3        band-4        band-5  \
# count  21025.000000  21025.000000  21025.000000  21025.000000  21025.000000
# mean    2957.363472   4091.321237   4277.502259   4169.956671   4516.678668
# std      354.918708    230.390005    257.827640    280.761254    346.035984
# min     2560.000000   2709.000000   3649.000000   2810.000000   3840.000000
# 25%     2602.000000   3889.000000   4066.000000   3954.000000   4214.000000
# 50%     2780.000000   4106.000000   4237.000000   4126.000000   4478.000000
# 75%     3179.000000   4247.000000   4479.000000   4350.000000   4772.000000
# max     4536.000000   5744.000000   6361.000000   6362.000000   7153.000000
#
#              band-6        band-7        band-8        band-9       band-10  \
# count  21025.000000  21025.000000  21025.000000  21025.000000  21025.000000
# mean    4790.595149   4848.317574   4714.732509   4668.904828   4439.065541
# std      414.382138    469.247667    491.728349    533.232855    539.908195
# min     4056.000000   4004.000000   3865.000000   3775.000000   2792.000000
# 25%     4425.000000   4421.000000   4263.000000   4173.000000   3940.000000
# 50%     4754.000000   4808.000000   4666.000000   4632.000000   4404.000000
# 75%     5093.000000   5198.000000   5100.000000   5084.000000   4860.000000
# max     7980.000000   8284.000000   8128.000000   8194.000000   7928.000000
#
#        ...      band-192      band-193      band-194      band-195  \
# count  ...  21025.000000  21025.000000  21025.000000  21025.000000
# mean   ...   1061.927848   1060.210273   1063.276813   1050.048514
# std    ...     38.843805     38.712195     41.920969     34.242725
# min    ...    998.000000    999.000000    999.000000    993.000000
# 25%    ...   1026.000000   1024.000000   1024.000000   1019.000000
# 50%    ...   1053.000000   1052.000000   1054.000000   1043.000000
# 75%    ...   1099.000000   1098.000000   1104.000000   1083.000000
# max    ...   1287.000000   1289.000000   1315.000000   1258.000000
#
#            band-196      band-197      band-198      band-199      band-200  \
# count  21025.000000  21025.000000  21025.000000  21025.000000  21025.000000
# mean    1040.201141   1043.370321   1030.194816   1015.571463   1008.513579
# std       26.452672     29.794418     20.865106     11.386402      7.050921
# min      990.000000    992.000000    989.000000    986.000000    981.000000
# 25%     1016.000000   1016.000000   1012.000000   1006.000000   1004.000000
# 50%     1033.000000   1035.000000   1026.000000   1014.000000   1009.000000
# 75%     1066.000000   1072.000000   1050.000000   1024.000000   1014.000000
# max     1201.000000   1245.000000   1167.000000   1076.000000   1036.000000
#
#               class
# count  21025.000000
# mean       4.224923
# std        5.281972
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       10.000000
# max       16.000000
#
# [8 rows x 201 columns]

# %% [markdown]
# ### 3. Analysis

# %%
df.head()
# Out:
#    band-1  band-2  band-3  band-4  band-5  band-6  band-7  band-8  band-9  \
# 0    3172    4142    4506    4279    4782    5048    5213    5106    5053
# 1    2580    4266    4502    4426    4853    5249    5352    5353    5347
# 2    3687    4266    4421    4498    5019    5293    5438    5427    5383
# 3    2749    4258    4603    4493    4958    5234    5417    5355    5349
# 4    2746    4018    4675    4417    4886    5117    5215    5096    5098
#
#    band-10  ...  band-192  band-193  band-194  band-195  band-196  band-197  \
# 0     4750  ...      1094      1090      1112      1090      1062      1069
# 1     5065  ...      1108      1104      1117      1091      1079      1085
# 2     5132  ...      1111      1114      1114      1100      1065      1092
# 3     5096  ...      1122      1108      1109      1109      1071      1088
# 4     4834  ...      1110      1107      1112      1094      1072      1087
#
#    band-198  band-199  band-200  class
# 0      1057      1020      1020      3
# 1      1064      1029      1020      3
# 2      1061      1030      1016      3
# 3      1060      1030      1006      3
# 4      1052      1034      1019      3
#
# [5 rows x 201 columns]

# %% [markdown]
# Showing randomly 6 rows of the dataset

# %%
df.sample(6)
# Out:
#        band-1  band-2  band-3  band-4  band-5  band-6  band-7  band-8  band-9  \
# 11307    3014    4248    4393    4188    4638    4910    4952    4814    4812
# 15353    3191    3991    4321    4151    4569    4812    4915    4704    4650
# 17648    3319    3845    4023    3950    4040    4377    4378    4202    4056
# 9538     2607    3867    4213    3951    4158    4324    4315    4134    4064
# 2359     3156    4130    4243    4185    4468    4706    4729    4627    4598
# 16596    2733    4091    4024    4038    4224    4388    4554    4261    4293
#
#        band-10  ...  band-192  band-193  band-194  band-195  band-196  \
# 11307     4629  ...      1040      1046      1043      1033      1033
# 15353     4388  ...      1026      1028      1029      1020      1023
# 17648     3891  ...      1018      1022      1021      1020      1010
# 9538      3873  ...      1023      1021      1016      1009      1006
# 2359      4377  ...      1086      1084      1085      1080      1040
# 16596     4000  ...      1034      1034      1029      1031      1031
#
#        band-197  band-198  band-199  band-200  class
# 11307      1028      1029      1004      1003      0
# 15353      1028      1011      1013      1018      0
# 17648      1007      1003      1000      1008     14
# 9538       1004      1006       991       995      0
# 2359       1059      1041      1024      1015     12
# 16596      1019      1017      1008      1008      6
#
# [6 rows x 201 columns]

# %%
print(f'Shape of the data: {df.shape}')
# Out:
# Shape of the data: (21025, 201)

# %%
print(f"Unique Class Labels: {df.loc[:, 'class'].unique()}")
# Out:
# Unique Class Labels: [ 3  0 15 11 12  5 10 14 16  2  4  8  6  9  1  7 13]

# %%
df.loc[:, 'class'].value_counts()
# Out:
# 0     10776
# 11     2455
# 2      1428
# 14     1265
# 10      972
# 3       830
# 6       730
# 12      593
# 5       483
# 8       478
# 15      386
# 4       237
# 13      205
# 16       93
# 1        46
# 7        28
# 9        20
# Name: class, dtype: int64

# %%
plt.figure(figsize=(14, 8))

ax = sns.countplot(x='class', data=df[['class']])

for p in ax.patches:
        ax.annotate('{:.1f}%'.format(100*p.get_height()/df.shape[0]), (p.get_x()+0.1, p.get_height()+5))


plt.ylabel('Class count with percentage', fontsize=14)

plt.xlabel('class', fontsize=14)

plt.title('Bar Plot', fontsize=16)

plt.show()

# %% [markdown]
# ### 4. Visualizing pixels of the Indian Pines HSI
#
# Usually the pixel of the indian pines HSI is a one dimensional vector with size (1, 200) ad the HSI has 200 bands.
#
# To visualize a vector is shown below:

# %%
# Visualizing the pixel
plt.matshow(df.iloc[1, :-1].values.reshape(1,200), cmap='jet');

# %% [markdown]
# It is difficult to interpret the visualization of a vetor. So, to overcome this problem the pixel vector is reshape into a 2-Dimensional array.
# * 200 => 10 X 20
# * (1, 200) => (10, 20)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
def plot_pixel(pixel, n):
    ax = plt.gca()
    im = ax.imshow(pixel.reshape(10, 20), cmap = 'jet')
    plt.title(f'pixel - {n}')
    plt.axis('off')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    plt.show()

# %%
plt.figure(figsize=(8, 4))

rand_n = np.random.randint(df.shape[0])

plot_pixel(df.iloc[rand_n, :-1].values, rand_n)

# %% [markdown]
# ### 5. Box plot w.r.t bands of the HSI

# %%
plt.figure(figsize=(16, 6))
n = int(input('Enter the band Number(1-200) :'))
sns.boxplot( x=df["class"], y=df["band-1"], width=0.3);
plt.title('Box Plot', fontsize= 16)
plt.xlabel('Class', fontsize= 14)
plt.ylabel(f'Band-{n}', fontsize= 14)
plt.show()
# Out:
# Enter the band Number(1-200) : 15

# %% [markdown]
# ### 6. Distribution Plot

# %%
print(f"Details of Band - {n}: \n\n{df['band-'+str(n)].describe()}")
# Out:
# Details of Band - 15:
#
# count    21025.000000
# mean      4470.958811
# std        634.474623
# min       2665.000000
# 25%       3958.000000
# 50%       4399.000000
# 75%       4924.000000
# max       7948.000000
# Name: band-15, dtype: float64

# %%
plt.figure(figsize=(16, 6))
sns.distplot(df['band-'+str(n)], color='mediumSpringGreen', bins=100, hist_kws={'alpha': 0.4});
plt.xlabel('Band - '+str(n), fontsize=14)
plt.title('Disrtibution Plot of Band - '+str(n), fontsize=16)
plt.show()
# Out:
# /home/aravind/.local/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
